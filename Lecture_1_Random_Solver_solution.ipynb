# %% [markdown]
# ## Artificial Intelligence (BSc) SA 2025-2026
#
# - Prof. Luca Gambardella
# - Fatima Ezzeddine ([`fatima.ezzeddine@usi.ch`](mailto:fatima.ezzeddine@usi.ch))<br>
#
# ---
# # Lab 1: Introduction to TSP and JSP problem formulation and to Mealpy
#
# Lab Objectives:
#
# Traveling Salesman Problem:
# - read TSP data
# - define euclidean distance function
# - define a TSPProblemInstance python class
# - plot raw data
# - generate naive solution
# - check if the solution is valid
# - evaluate solution
#
#
# Job Shop Scehduling Problem:
# - read JSP data
# - define objective function
# - use mealpy algorithm to get a solution
# - plot gant chart for solution
#
#
# NOTE: I've marked all the code that you will have to fill with a `# TODO` comment

# %% [markdown]
# This cell below is simply importing some useful stuff for later

# %%
# # example of how to install a library in python
# !pip install numpy
# !pip install mealpy
# !pip install matplotlib

# %%
# !python3 --version

# %%
# The glob module finds all the pathnames matching a specified pattern
import glob

# Numpy library used for working with arrays, has functions for working in domain of linear algebra, and matrices
import numpy as np

# Matplotlib is a library for creating visualizations
from matplotlib import pyplot as plt

# %% [markdown]
# ### Read TSP data
# In this Cup you will have to deal with predefined set of problems. These problems are located in the `problems` folder.
#
# First lets get list them out

# %%
# read all the files that has extention .tsp to the problems array object
problems = glob.glob('./problems/*.tsp')

# loop over the problems and print the problem name 
for prob in problems:
    print(prob[11:])
# Out:
# fl1577.tsp
# lin318.tsp
# kroA100.tsp
# d198.tsp
# pr439.tsp
# rat783.tsp
# eil76.tsp
# u1060.tsp
# ch130.tsp
# pcb442.tsp

# %%
# Checking if all of the 10 problems are in the folder would be a waste of time so we can write a line of code just to check if they are all there
print(np.all([n[11:] in ['fl1577.tsp','pr439.tsp','ch130.tsp','rat783.tsp','d198.tsp', 'kroA100.tsp','u1060.tsp','lin318.tsp','eil76.tsp','pcb442.tsp'] for n in problems]))
# Out:
# True

# %% [markdown]
# #### TSP File format
# All the problems are stored in a `.tsp` (this file is actually a renamed `.txt` file, so you could open them with your favorite text editor)
#
# As we will see in a bit all the problems files are composed of different sections:
# * `NAME`: the shortned name of the problem
# * `COMMENT`: a comment area that can contain the full name of the problem
# * `TYPE`: this defines the type of problem at hand, in our case is always TSP
# * `DIMENSION`: this states the problem dimension
# * `EDGE_WEIGHT_TYPE`: this section states the types of weights applied to edges, in our case it is always EUC_2D or the weights are giveng using the euclidean distance in 2 dimension
# * `BEST_KNOWN`: this states the best known result obtained, note that as the Prof said, it is unlikely to get a better performance than this
# * `NODE_COORD_SECTION`: finally we have the section that states the triplets that defines the problems points. These triplets are (point_number, x,y).
#
# Now that we know all of that, lets print the content of a single problem

# %%
example_problem = "./problems/eil76.tsp"
# open problem file as read and print it's content lines
with open(example_problem,"r") as exprob:
    print(exprob.read().splitlines())
# Out:
# ['NAME: eil76', 'COMMENT: 76-city problem (Christofides/Eilon)', 'TYPE: TSP', 'DIMENSION: 76', 'EDGE_WEIGHT_TYPE: EUC_2D', 'BEST_KNOWN: 538', 'NODE_COORD_SECTION', '1 22 22', '2 36 26', '3 21 45', '4 45 35', '5 55 20', '6 33 34', '7 50 50', '8 55 45', '9 26 59', '10 40 66', '11 55 65', '12 35 51', '13 62 35', '14 62 57', '15 62 24', '16 21 36', '17 33 44', '18 9 56', '19 62 48', '20 66 14', '21 44 13', '22 26 13', '23 11 28', '24 7 43', '25 17 64', '26 41 46', '27 55 34', '28 35 16', '29 52 26', '30 43 26', '31 31 76', '32 22 53', '33 26 29', '34 50 40', '35 55 50', '36 54 10', '37 60 15', '38 47 66', '39 30 60', '40 30 50', '41 12 17', '42 15 14', '43 16 19', '44 21 48', '45 50 30', '46 51 42', '47 50 15', '48 48 21', '49 12 38', '50 15 56', '51 29 39', '52 54 38', '53 55 57', '54 67 41', '55 10 70', '56 6 25', '57 65 27', '58 40 60', '59 70 64', '60 64 4', '61 36 6', '62 30 20', '63 20 30', '64 15 5', '65 50 70', '66 57 72', '67 45 42', '68 38 33', '69 50 4', '70 66 8', '71 59 5', '72 35 60', '73 27 24', '74 40 20', '75 40 37', '76 40 40', 'EOF']

# %% [markdown]
# ### Euclidean Distance
# Since all of our problems are using the euclidean distance between points for the edges weights.
# We will now define a function that computes the euclidean distance. This distance will also be used to build the distance matrix

# %%
#define function to compute euclidean distance between 2 points
def distance_euc(point_i, point_j):
    rounding = 0
    x_i, y_i = point_i[0], point_i[1]
    x_j, y_j = point_j[0], point_j[1]
    # use the numpy sqrt method
    distance = np.sqrt((x_i - x_j) ** 2 + (y_i - y_j) ** 2)
    return round(distance, rounding)

# %% [markdown]
# Let's test it

# %%
point_1 = (2, 2)
point_2 = (5, 5)
distance_euc(point_1, point_2)
# Expected output is 4.0 with rounding to 0
# Out:
# 4.0

# %%
text = 'NAME: eil76'
text.split(' ')
# Out:
# ['NAME:', 'eil76']

# %% [markdown]
# ### Reading and storing the data
# We will now define a Class called `ProblemInstance`
#
# in the Constructor of the class (`__init__()`method of a class in Python) you will have to implement the code for:
# * reading the raw data
# * store the metadata
# * read all the point and store them
# * code the method that creates the distance matrix between points
# * \[optional\] check if the problem loaded has an optimal and in that case store the optimal solution
# * \[optional\] code the plotting method

# %%
class ProblemInstance:

    def __init__(self, name_tsp):

        # boolean if the problem have an sxisting optimal solution
        self.exist_opt = False

        # the optimal tour that was found before
        self.optimal_tour = None

        # distance matrix
        # Example distance matrix representing distances between 4 points
        #    A    B    C    D
        # A  0.0  2.5  3.0  4.2
        # B  2.5  0.0  1.8  3.6
        # C  3.0  1.8  0.0  2.9
        # D  4.2  3.6  2.9  0.0
        self.dist_matrix = None
        
        # read raw data  
        with open(name_tsp) as f_o:
            data= f_o.read()
            self.lines = data.splitlines()

        # store metadata set information 

        # here we expect the name of the problem
        self.name = self.lines[0].split(' ')[1]
        

        # here we expect the number of points in the considered instance
        self.nPoints =  int(self.lines[3].split(' ')[1])
        
        # here the length of the best solution
        self.best_sol = float(self.lines[5].split(' ')[1])
        
        
        # read all data points and store them 
        self.points = np.zeros((self.nPoints, 3)) # this is the structure where we will store the pts data 
        for i in range(self.nPoints):
            line_i = self.lines[7 + i].split(' ')
            self.points[i, 0] = int(line_i[0])
            self.points[i, 1] = float(line_i[1])
            self.points[i, 2] = float(line_i[2])

        # create distance matrix bx calling create_dist_matrix
        self.create_dist_matrix()
        
        # TODO [optional]
        # if the problem is one with a optimal solution, that solution is loaded
        self.optimal_tour = np.zeros(self.nPoints, dtype=int)
        if name_tsp in ["./problems/eil76.tsp", "./problems/kroA100.tsp"]:
            # change the boolean to True since an optimal solution exist
            self.exist_opt = True
            # open the optimal solution file and read it
            file_object = open(name_tsp.replace(".tsp", ".opt.tour"))
            data = file_object.read()
            file_object.close()
            lines = data.splitlines()

            # read all data points and store them

            # initialize an array with 0s using np.zeros
            self.optimal_tour = np.zeros(self.nPoints, dtype=int)
            # read the points from the file and fill the array
            for i in range(self.nPoints):
                line_i = lines[5 + i].split(' ')
                self.optimal_tour[i] = int(line_i[0]) - 1

    # for display purposes
    def print_info(self):
        print("\n#############################\n")
        print('name: ' + self.name)
        print('nPoints: ' + str(self.nPoints))
        print('best_sol: ' + str(self.best_sol))
        print('exist optimal: ' + str(self.exist_opt))

    # for display purposes
    def plot_data(self,show_numbers=False):
        # define a figure with it's size
        plt.figure(figsize=(8, 8))

        # give it a title as the problem instance name
        plt.title(self.name)

        # scatter takes an x and y axis values that are in this case the points that we have
        plt.scatter(self.points[:, 1], self.points[:, 2])

        # if we want to add to the plot next to each point it's number or id
        if show_numbers:
            for i, txt in enumerate(np.arange(self.nPoints)): 
                plt.annotate(txt, (self.points[i, 1], self.points[i, 2]))

        # display the plot/figure        
        plt.show()

    def create_dist_matrix(self): # TODO
        # initialize the matrix with dimension n x n
        self.dist_matrix = np.zeros((self.nPoints, self.nPoints))

        # loop over all the pints and compute the euclidean distance between every pair of points with index i and j
        for i in range(self.nPoints):
            for j in range(i, self.nPoints):
                self.dist_matrix[i, j] = distance_euc(self.points[i][1:3], self.points[j][1:3])

        # transpose of the matrix and fill missing other 0s
        # this was made to reduce the complexity  
        self.dist_matrix += self.dist_matrix.T

# %% [markdown]
# ------------------------
# Now we can test our Class with an example problem

# %%
example_problem = "./problems/eil76.tsp"
p_inst = ProblemInstance(example_problem)

p_inst.print_info()
p_inst.plot_data()
#Expected output
"""
#############################

name: eil76
nPoints: 76
best_sol: 538.0
exist optimal: True
"""
# Out:
# #############################
#
# name: eil76
# nPoints: 76
# best_sol: 538.0
# exist optimal: True
# '\n#############################\n\nname: eil76\nnPoints: 76\nbest_sol: 538.0\nexist optimal: True\n'

# %%
p_inst.nPoints
# Out:
# 76

# %%
p_inst.plot_data(show_numbers=True)

# %% [markdown]
# -------------
# ### Random solver
# Now we will code the random solver and test it with a class called `SolverTSP` that takes the solvers and the problem instance and act as a framework to compute the solution and gives us some additional information.
# We will also need to code the `evaluate_solution` method of the the `SolverTSP` class

# %%
# Generate a random permutation of numbers from 0 to instance_.nPoints - 1.
#  This is done using np.arange(instance_.nPoints), which creates an array of integers from 0 to instance_.nPoints - 1.

# np.random.choice is then used to randomly shuffle this array. 
# It essentially selects elements from the array in a random order without replacement, ensuring that each element is selected exactly once.

#The result is an array containing a random permutation of integers from 0 to instance_.nPoints - 1.

def random_method(instance_): # TODO
    return np.random.choice(np.arange(instance_.nPoints), size=instance_.nPoints,
                            replace=False)

print(random_method(p_inst))
# Out:
# [58 54 65 10 49 21 57 13 42 38 47 45 40 71 62 24 26 61 75 33 52 66 15 17
#  53 55 73  7 16 51 27 30  6 35 74  2 28 67 43 36 63 37 11 60 23 29 18 44
#   3 56  1 46 19 32 39 22 50 14 31 41 68 25 59 69  9 48 72  5  8  4 20 64
#  34  0 70 12]

# %%
available_methods = {"random": random_method}

# %%
# library to get time
from time import time as t

class SolverTSP:
    def __init__(self, algorithm_name, problem_instance):
        # duration taken to find the solution
        self.duration = np.inf

        # lenght of the tour found by the solver
        self.found_length = np.inf

        # name of the algorithm
        self.algorithm_name = algorithm_name

        # initialization
        self.name_method = "initialized with " + algorithm_name

        # boolean to check if solved problem
        self.solved = False

        # TSP problem intance to be solved
        self.problem_instance = problem_instance

        # the found solution
        self.solution = None

    # function that takes computes the solution by applying the function given as input
    def compute_solution(self, verbose=True, return_value=True):
        self.solved = False
        if verbose:
            print(f"###  solving with {self.algorithm_name}  ####")
        
        # starting time 
        start_time = t()

        # available methods that was defined earlier have a pointer to the function (algorithm name) and take as input the problem instance
        self.solution = available_methods[self.algorithm_name](self.problem_instance)

        # check if solution is valid implemented
        assert self.check_if_solution_is_valid(self.solution), "Error the solution is not valid"
        #end time of the solution
        end_time = t()
        self.duration = np.around(end_time - start_time, 3)
        if verbose:
            print(f"###  solved  ####")
        self.solved = True
        # compute the length of the solution tour
        self.evaluate_solution()

        # compute the gap
        self._gap()

        if return_value:
            return self.solution

    # simple plot of the soluton found
    def plot_solution(self):
        assert self.solved, "You can't plot the solution, you need to compute it first!"
        plt.figure(figsize=(8, 8))
        self._gap()
        plt.title(f"{self.problem_instance.name} solved with {self.name_method} solver, gap {self.gap}")
        ordered_points = self.problem_instance.points[self.solution]
        plt.plot(ordered_points[:, 1], ordered_points[:, 2], 'b-')
        plt.show()

    # check if the solution contains all the point and visited exactly one
    def check_if_solution_is_valid(self, solution):
        rights_values = np.sum([self.check_validation(i, solution) for i in np.arange(self.problem_instance.nPoints)])
        if  rights_values == self.problem_instance.nPoints:
            return True
        else:
            return False 
        
    # check if a point/node inside a solution 
    def check_validation(self, node , solution):
         if np.sum(solution == node) == 1:
            return 1
         else:
            return 0

    # compute the tour lengh by the help of distance matrix already computed
    def evaluate_solution(self, return_value=False):
        total_length = 0
        from_node_id = self.solution[0] # starting_node

        # loop over all the nodes and add successive distances
        for node_id in self.solution[1:]:
            edge_distance = self.problem_instance.dist_matrix[from_node_id, node_id]
            total_length += edge_distance
            from_node_id = node_id

        # have a complete tour and add the distance to go back to starting node    
        self.found_length = total_length + self.problem_instance.dist_matrix[self.solution[0], from_node_id]       
        if return_value:
            return total_length

    # compute (solution - best solution)/best solution in %
    def _gap(self):
        self.evaluate_solution(return_value=False)
        self.gap = np.round(
            ((self.found_length - self.problem_instance.best_sol) / self.problem_instance.best_sol) * 100, 2)

# %% [markdown]
# ----------------------------
# Now we will test our code

# %%
# here I'm repeating this two lines just to remind you which problem we are using
example_problem = "./problems/eil76.tsp"
p_inst = ProblemInstance(example_problem)
available_methods = {"random": random_method}
solver_name="random"
# TODO
# 1. create an instance of SolverTSP
solver = SolverTSP(solver_name, p_inst)
# 2. compute a solution
solver.compute_solution()
# 3. print the information as for the output
print(f"the total length for the solution found is {solver.found_length}",
      f"while the optimal length is {solver.problem_instance.best_sol}",
      f"the gap is {solver.gap}%",
      f"the solution is found in {solver.duration} seconds", sep="\n")
# 4. plot the solution
solver.plot_solution()
# this is the output expected and after that the solution's plot
"""
###  solving with random  ####
###  solved  ####
the total length for the solution found is 2424.0
while the optimal length is 538.0
the gap is 350.56%
the solution is found in 0.0 seconds
"""
# Out:
# ###  solving with random  ####
# ###  solved  ####
# the total length for the solution found is 2581.0
# while the optimal length is 538.0
# the gap is 379.74%
# the solution is found in 0.0 seconds
# '\n###  solving with random  ####\n###  solved  ####\nthe total length for the solution found is 2424.0\nwhile the optimal length is 538.0\nthe gap is 350.56%\nthe solution is found in 0.0 seconds\n'

# %% [markdown]
# --------------------
# Finally since our example problem has an optimal solution we can plot it

# %%
solver = SolverTSP("optimal", p_inst)
solver.solved = True
# the solution is the optimal tour
solver.solution = np.concatenate([p_inst.optimal_tour, [p_inst.optimal_tour[0]]])
solver.plot_solution()

# %% [markdown]
# ### JOB SHOP SCHEDULING
# JSPLIB
# - "name" : "instance", // the name of the instance [required]
# - "jobs" : n,          // the number of jobs [required]
# - "machines" : m,      // the number of machines [required]
# - "optimum" : c,       // the optimum makespan or null [required]
# - "bounds" :          // required when the optimum is null
# - "upper" : ub,       // the upper-bounds of makespan
# - "lower" : lb,       // the lower-bounds of makespan
# - "path" : "*****"     // the file path to the instance [required]

# %%
# coding: utf-8
import os
import sys
import json
import math
import numpy as np

Target = 'abz5'

file = open('./JSPLIB-master/instances.json', "r" )
data = json.load(file)

instance = [ inst for inst in data if inst['name'] == Target ]
if(len(instance) == 0):
    raise Exception("There is no instance named %s" % Target)

instance = instance[0]
path = os.path.abspath("../%s" % instance['path'])
optimum = instance['optimum']

if( optimum is None ):
    if(instance['bounds'] is None):
        optimum = "nan"
    else:
        optimum = instance['bounds']['lower']

sys.stdout.write('--instance %s --optimum %s' % (path,optimum))
# Out:
# --instance /home/fatimaezzedine/PycharmProjects/Vs Code Repo copy/instances/abz5 --optimum 1234
# 95

# %%
optimum
# Out:
# 1234

# %%
# EXAMPLE OF HOW JOBS SHOULD BE PRESENTED
job_times = [[2, 1, 3], [4, 2, 1], [3, 3, 2]] # [0, 1, 2, 3, 4, 5, 6 ,7, 8] (how represented in the solution, flatten and re-enumerated)
# job 0: [2, 1, 3]
# Machine 1: 2, index 0 in the solution
# Machine 2: 1  index 1 in the solution
# Machine 3: 3  index 2 in the solution
# etc. same for the others
# job_times[i][j] represents the processing time of job i on machine j.
# The objective is typically to minimize the total time required to complete all jobs (the makespan).

path_file = './JSPLIB-master/instances/abz5'

# read raw data
with open(path_file) as f_o:
    data = f_o.read()
    lines = data.splitlines()
    print(lines)

jobs = np.zeros((10, 10))
lines = lines[5:]
lines, len(lines)

for i in range(len(lines)):
    line = lines[i].split(' ')
    line = [int(num) for num in line]
    for j in range(0, len(line) -1 , 2):
        jobs[i][line[j]] = int(line[j+1])
jobs
# Out:
# ['#+++++++++++++++++++++++++++++', '# instance abz5', '#+++++++++++++++++++++++++++++', '# Adams, Balas, and Zawack 10x10 instance (Table 1, instance 5)', '10 10', '4 88 8 68 6 94 5 99 1 67 2 89 9 77 7 99 0 86 3 92', '5 72 3 50 6 69 4 75 2 94 8 66 0 92 1 82 7 94 9 63', '9 83 8 61 0 83 1 65 6 64 5 85 7 78 4 85 2 55 3 77', '7 94 2 68 1 61 4 99 3 54 6 75 5 66 0 76 9 63 8 67', '3 69 4 88 9 82 8 95 0 99 2 67 6 95 5 68 7 67 1 86', '1 99 4 81 5 64 6 66 8 80 2 80 7 69 9 62 3 79 0 88', '7 50 1 86 4 97 3 96 0 95 8 97 2 66 5 99 6 52 9 71', '4 98 6 73 3 82 2 51 1 71 5 94 7 85 0 62 8 95 9 79', '0 94 6 71 3 81 7 85 1 66 2 90 4 76 5 58 8 93 9 97', '3 50 0 59 1 82 8 67 7 56 9 96 6 58 4 81 5 59 2 96']
# array([[86., 67., 89., 92., 88., 99., 94., 99., 68., 77.],
#        [92., 82., 94., 50., 75., 72., 69., 94., 66., 63.],
#        [83., 65., 55., 77., 85., 85., 64., 78., 61., 83.],
#        [76., 61., 68., 54., 99., 66., 75., 94., 67., 63.],
#        [99., 86., 67., 69., 88., 68., 95., 67., 95., 82.],
#        [88., 99., 80., 79., 81., 64., 66., 69., 80., 62.],
#        [95., 86., 66., 96., 97., 99., 52., 50., 97., 71.],
#        [62., 71., 51., 82., 98., 94., 73., 85., 95., 79.],
#        [94., 66., 90., 81., 76., 58., 71., 85., 93., 97.],
#        [59., 82., 96., 50., 81., 59., 58., 56., 67., 96.]])

# %%
# # abz5 instance
# job_times =[[86., 67., 89., 92., 88., 99., 94., 99., 68., 77.], 
#             [92., 82., 94., 50., 75., 72., 69., 94., 66., 63.],
#               [83., 65., 55., 77., 85., 85., 64., 78., 61., 83.],
#                 [76., 61., 68., 54., 99., 66., 75., 94., 67., 63.], 
#                  [99., 86., 67., 69., 88., 68., 95., 67., 95., 82.],
#                   [88., 99., 80., 79., 81., 64., 66., 69., 80., 62.],
#                     [95., 86., 66., 96., 97., 99., 52., 50., 97., 71.],
#                       [62., 71., 51., 82., 98., 94., 73., 85., 95., 79.],
#                         [94., 66., 90., 81., 76., 58., 71., 85., 93., 97.],
#                           [59., 82., 96., 50., 81., 59., 58., 56., 67., 96.]]

# %%
from mealpy import PermutationVar, Problem, WOA

job_times = jobs
n_jobs = len(job_times)
n_machines = 10


data = {
    "job_times": job_times,
    "n_jobs": n_jobs,
    "n_machines": n_machines
}

# The only thing that you have to implement is the objective function
class JobShopProblem(Problem):
    def __init__(self, bounds=None, minmax="min", data=None, **kwargs):
        self.data = data
        super().__init__(bounds, minmax, **kwargs)

        # Objective function to minimize the makespan
    def obj_func(self, x):
        x_decoded = self.decode_solution(x)
        x = x_decoded["per_var"]

        # Initialize the makespan matrix with zeroes for all jobs and machines
        makespan = np.zeros((self.data["n_jobs"], self.data["n_machines"]))
        
        # MakeSpan:  [[0. 0. 0.]
        #             [0. 0. 0.]
        #             [0. 0. 0.]]
        # makespan[i][j]: each row i represent a job idx, each column j repesent a machine idx
        
        # Arrays to track the completion time of each job and each machine
        job_completion = np.zeros(self.data["n_jobs"])
        machine_completion = np.zeros(self.data["n_machines"])

        # Iterates over the jobs in the solution order and calculates the completion time of each job on each machine.
        # Uses a makespan matrix to keep track of the completion times of jobs on each machine.
        # The final makespan is the maximum value in the makespan matrix, which represents the completion time of the last job.
        for gene in x:
            # Decode gene into job and machine indices
            job_idx = gene // self.data["n_machines"]
            machine_idx = gene % self.data["n_machines"]
            
            # Completion time for this job on this machine depends on two things:
            # 1. The time when the machine becomes available (from previous job)
            # 2. The time when the job is ready to be processed on this machine (from previous machine)
            
            start_time = max(job_completion[job_idx], machine_completion[machine_idx])
            
            # Update the makespan matrix with start time + processing time
            makespan[job_idx][machine_idx] = start_time + self.data["job_times"][job_idx][machine_idx]
            
            # Update the completion time of this job and this machine
            job_completion[job_idx] = makespan[job_idx][machine_idx]
            machine_completion[machine_idx] = makespan[job_idx][machine_idx]
        
        # The makespan (objective value) is the maximum value in the makespan matrix
        return np.max(makespan)
        

bounds = PermutationVar(valid_set=list(range(0, n_jobs*n_machines)), name="per_var")
problem = JobShopProblem(bounds=bounds, minmax="min", data=data)

model = WOA.OriginalWOA(epoch=1000, pop_size=20)
model.solve(problem)

print(f"Best agent: {model.g_best}")                    # Encoded solution
print(f"Best solution: {model.g_best.solution}")        # Encoded solution
print(f"Best fitness: {model.g_best.target.fitness}")
print(f"Best real scheduling: {model.problem.decode_solution(model.g_best.solution)}")      # Decoded (Real) solution
# Out:
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: Solving single objective optimization problem.
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 1, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00466 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 2, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00482 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 3, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00507 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 4, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00645 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 5, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00541 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 6, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00870 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 7, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00689 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 8, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00588 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 9, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00546 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 10, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00539 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 11, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00504 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 12, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00496 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 13, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00528 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 14, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00505 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 15, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 16, Current best: 1684.0, Global best: 1684.0, Runtime: 0.00483 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 17, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00657 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 18, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00869 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 19, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00509 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 20, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00480 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 21, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 22, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00513 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 23, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00514 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 24, Current best: 1645.0, Global best: 1645.0, Runtime: 0.00495 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 25, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00478 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 26, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00473 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 27, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00489 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 28, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00483 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 29, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00488 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 30, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00480 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 31, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00498 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 32, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00486 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 33, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00492 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 34, Current best: 1642.0, Global best: 1642.0, Runtime: 0.00539 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 35, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00546 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 36, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00746 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 37, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00496 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 38, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00500 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 39, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00624 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 40, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00486 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 41, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00495 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 42, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00533 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 43, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00523 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 44, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00595 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 45, Current best: 1590.0, Global best: 1590.0, Runtime: 0.00529 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 46, Current best: 1568.0, Global best: 1568.0, Runtime: 0.00492 seconds
# 2025/09/23 10:26:10 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 47, Current best: 1568.0, Global best: 1568.0, Runtime: 0.00482 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 48, Current best: 1568.0, Global best: 1568.0, Runtime: 0.00569 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 49, Current best: 1568.0, Global best: 1568.0, Runtime: 0.00492 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 50, Current best: 1568.0, Global best: 1568.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 51, Current best: 1568.0, Global best: 1568.0, Runtime: 0.00474 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 52, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00526 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 53, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00506 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 54, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00510 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 55, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00523 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 56, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00492 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 57, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00504 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 58, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00490 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 59, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00488 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 60, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00503 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 61, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00486 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 62, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00490 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 63, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00545 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 64, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00495 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 65, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00476 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 66, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00468 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 67, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00462 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 68, Current best: 1567.0, Global best: 1567.0, Runtime: 0.00511 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 69, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00671 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 70, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00677 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 71, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00567 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 72, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00542 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 73, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00591 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 74, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00481 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 75, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00472 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 76, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00484 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 77, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00478 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 78, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 79, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00479 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 80, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00482 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 81, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00478 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 82, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00621 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 83, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00518 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 84, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00509 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 85, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00712 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 86, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00747 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 87, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00604 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 88, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00516 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 89, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00485 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 90, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00595 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 91, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00504 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 92, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00501 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 93, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00469 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 94, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00569 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 95, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00640 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 96, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00606 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 97, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00600 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 98, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00516 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 99, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00519 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 100, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00603 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 101, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 102, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00506 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 103, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00511 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 104, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00533 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 105, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00513 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 106, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00512 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 107, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00487 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 108, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00487 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 109, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00584 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 110, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00495 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 111, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00503 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 112, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00522 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 113, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00490 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 114, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 115, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00508 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 116, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00485 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 117, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 118, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00502 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 119, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00493 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 120, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00563 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 121, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00484 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 122, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00521 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 123, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00503 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 124, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00527 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 125, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00515 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 126, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00501 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 127, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00506 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 128, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00495 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 129, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00662 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 130, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00518 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 131, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00603 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 132, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 133, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00509 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 134, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00489 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 135, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00481 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 136, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00473 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 137, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00496 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 138, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00533 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 139, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 140, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00525 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 141, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00484 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 142, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00526 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 143, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00533 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 144, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00533 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 145, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00885 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 146, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00530 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 147, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00626 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 148, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00506 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 149, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00533 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 150, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00498 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 151, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00558 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 152, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00478 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 153, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00500 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 154, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00499 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 155, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00510 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 156, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00515 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 157, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00532 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 158, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00547 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 159, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00473 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 160, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00624 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 161, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00614 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 162, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00483 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 163, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00480 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 164, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00477 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 165, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00511 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 166, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 167, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 168, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 169, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00524 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 170, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00585 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 171, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00495 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 172, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00620 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 173, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00499 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 174, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00700 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 175, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00660 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 176, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00504 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 177, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00514 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 178, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00649 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 179, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00485 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 180, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00492 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 181, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00509 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 182, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00483 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 183, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00542 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 184, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00505 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 185, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00490 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 186, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00513 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 187, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00510 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 188, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00530 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 189, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00511 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 190, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00558 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 191, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00540 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 192, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00536 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 193, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00485 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 194, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00520 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 195, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00646 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 196, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00696 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 197, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 198, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00466 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 199, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 200, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00507 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 201, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00545 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 202, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00503 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 203, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00568 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 204, Current best: 1536.0, Global best: 1536.0, Runtime: 0.00573 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 205, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00778 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 206, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00621 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 207, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00476 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 208, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 209, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00510 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 210, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 211, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00497 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 212, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00492 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 213, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00606 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 214, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00828 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 215, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00864 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 216, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00581 seconds
# 2025/09/23 10:26:11 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 217, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00661 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 218, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00535 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 219, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00523 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 220, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00508 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 221, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00507 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 222, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00511 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 223, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00504 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 224, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00509 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 225, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00484 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 226, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00531 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 227, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00553 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 228, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00658 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 229, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00758 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 230, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 231, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00513 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 232, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00510 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 233, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 234, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00500 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 235, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00537 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 236, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 237, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00504 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 238, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00534 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 239, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00472 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 240, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00499 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 241, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00505 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 242, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00474 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 243, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00504 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 244, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00505 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 245, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00540 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 246, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00460 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 247, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00519 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 248, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00473 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 249, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00483 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 250, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00466 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 251, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00507 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 252, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00489 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 253, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00472 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 254, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00764 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 255, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00512 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 256, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00507 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 257, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00502 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 258, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00503 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 259, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00496 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 260, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00493 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 261, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00489 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 262, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00513 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 263, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00516 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 264, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00526 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 265, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 266, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00680 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 267, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00522 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 268, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00531 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 269, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00598 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 270, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00535 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 271, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00611 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 272, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00508 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 273, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00506 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 274, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00610 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 275, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00526 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 276, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00527 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 277, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00524 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 278, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00535 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 279, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00575 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 280, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00521 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 281, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00712 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 282, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00497 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 283, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00556 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 284, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00756 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 285, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00524 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 286, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00485 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 287, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00538 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 288, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00781 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 289, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00501 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 290, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00473 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 291, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00531 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 292, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00486 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 293, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00467 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 294, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00547 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 295, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00482 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 296, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00471 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 297, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00463 seconds
# 2025/09/23 10:26:12 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 298, Current best: 1515.0, Global best: 1515.0, Runtime: 0.00476 seconds
# ...
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 909, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 910, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00472 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 911, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00479 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 912, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00499 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 913, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00473 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 914, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00459 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 915, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00472 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 916, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00484 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 917, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00486 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 918, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00478 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 919, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00480 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 920, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00513 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 921, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00498 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 922, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00479 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 923, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00470 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 924, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00481 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 925, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 926, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00563 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 927, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00727 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 928, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00554 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 929, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00496 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 930, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00515 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 931, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00529 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 932, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00542 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 933, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00476 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 934, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00485 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 935, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00525 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 936, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00529 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 937, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00480 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 938, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00489 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 939, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00506 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 940, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00485 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 941, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00462 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 942, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00488 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 943, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00530 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 944, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00512 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 945, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00511 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 946, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00502 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 947, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00498 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 948, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00490 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 949, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00480 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 950, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00489 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 951, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00478 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 952, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00489 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 953, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00491 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 954, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00526 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 955, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00487 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 956, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00493 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 957, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00608 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 958, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 959, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00466 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 960, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00510 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 961, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00479 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 962, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00500 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 963, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00498 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 964, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00471 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 965, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00566 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 966, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00473 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 967, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00506 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 968, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00484 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 969, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00482 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 970, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00550 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 971, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00490 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 972, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00514 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 973, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00520 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 974, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00478 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 975, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00750 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 976, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00469 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 977, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00500 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 978, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00494 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 979, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00472 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 980, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00486 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 981, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00498 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 982, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00477 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 983, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00508 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 984, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00483 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 985, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00479 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 986, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00467 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 987, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00513 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 988, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00500 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 989, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00471 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 990, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00487 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 991, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00444 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 992, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00481 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 993, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00487 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 994, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00540 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 995, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00500 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 996, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00466 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 997, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00479 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 998, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00517 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 999, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00496 seconds
# 2025/09/23 10:26:16 AM, INFO, mealpy.swarm_based.WOA.OriginalWOA: >>>Problem: P, Epoch: 1000, Current best: 1470.0, Global best: 1470.0, Runtime: 0.00467 seconds
# Best agent: id: 50480, target: Objectives: [1470.], Fitness: 1470.0, solution: [77 51 27 28 64  0 41 84 62 37 38 95 86 13 70  9 99 94 23 12 89 81 52 98
#  59 25 21 46 65 93 76  3 53 48 26 20 57 79 36 97 35 66 83 22 32 45 24 60
#  61 68 67 50 33 90 54 63 11 49 96 78 34 75 40 87 92 18 44 73  7  8 16 55
#  15  2 72 42 91 31 10 43  5  6 39 71 58 80 69 14 29 47  1 85 88 30  4 74
#  17 82 56 19]
# Best solution: [77 51 27 28 64  0 41 84 62 37 38 95 86 13 70  9 99 94 23 12 89 81 52 98
#  59 25 21 46 65 93 76  3 53 48 26 20 57 79 36 97 35 66 83 22 32 45 24 60
#  61 68 67 50 33 90 54 63 11 49 96 78 34 75 40 87 92 18 44 73  7  8 16 55
#  15  2 72 42 91 31 10 43  5  6 39 71 58 80 69 14 29 47  1 85 88 30  4 74
#  17 82 56 19]
# Best fitness: 1470.0
# Best real scheduling: {'per_var': [5, 90, 73, 31, 94, 80, 81, 68, 69, 15, 78, 56, 19, 13, 87, 72, 70, 96, 65, 99, 35, 26, 43, 18, 46, 25, 34, 2, 3, 88, 93, 77, 44, 52, 60, 40, 38, 9, 10, 82, 62, 6, 75, 79, 66, 45, 27, 89, 33, 57, 51, 1, 22, 32, 54, 71, 98, 36, 84, 24, 47, 48, 8, 55, 4, 28, 41, 50, 49, 86, 14, 83, 74, 67, 95, 61, 30, 0, 59, 37, 85, 21, 97, 42, 7, 91, 12, 63, 92, 20, 53, 76, 64, 29, 17, 11, 58, 39, 23, 16]}

# %%
def plot_gantt_chart(solution, job_times):
    n_jobs = len(job_times)
    n_machines = len(job_times[0])
    
    # Decode the solution
    decoded = problem.decode_solution(solution)["per_var"]
    
    # Initialize data structures
    job_completion = np.zeros(n_jobs)
    machine_completion = np.zeros(n_machines)
    tasks = []
    
    # Generate a color for each job
    colors = plt.cm.get_cmap('hsv', n_jobs)

    for gene in decoded:
        job_idx = gene // n_machines
        machine_idx = gene % n_machines
        start_time = max(job_completion[job_idx], machine_completion[machine_idx])
        end_time = start_time + job_times[job_idx][machine_idx]
        
        # Record the task for Gantt chart
        tasks.append((machine_idx, start_time, end_time, job_idx))
        
        # Update completion times
        job_completion[job_idx] = end_time
        machine_completion[machine_idx] = end_time
    
    # Plotting
    fig, gnt = plt.subplots(figsize=(16, 6))  # Set a larger figure size
    gnt.set_xlabel('Time')
    gnt.set_ylabel('Machines')
    gnt.set_title('Gantt Chart for Job Shop Scheduling')

    # Set the y-ticks to represent machines
    gnt.set_yticks(range(n_machines))
    gnt.set_yticklabels([f'Machine {i+1}' for i in range(n_machines)])

    # Add tasks to the Gantt chart
    for machine_idx, start_time, end_time, job_idx in tasks:
        gnt.broken_barh([(start_time, end_time - start_time)], (machine_idx - 0.4, 0.8), 
                         facecolors=colors(job_idx / n_jobs))  # Assign color based on job index
        gnt.text(start_time + (end_time - start_time) / 2, machine_idx, 
                 f'J {job_idx + 1}', ha='center', va='center', color='black')

    plt.show()

# After solving the problem, visualize the best solution
plot_gantt_chart(model.g_best.solution, job_times)
# Out:
# /tmp/ipykernel_212758/1367808067.py:14: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('hsv', n_jobs)

# %%
job_times
